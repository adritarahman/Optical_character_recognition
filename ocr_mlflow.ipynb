# %%
import mlflow
import os

# Path to your local mlruns folder
mlruns_path = os.path.abspath(r"C:\Users\Testing\OneDrive\Desktop\OCR\mlruns")

# Set MLflow tracking URI
mlflow.set_tracking_uri(f"file:///{mlruns_path.replace(os.sep, '/')}")

# %%
print(f"mlflow ui --backend-store-uri {mlflow.get_tracking_uri()}")
# Out:
# mlflow ui --backend-store-uri file:///C:/Users/Testing/OneDrive/Desktop/OCR/mlruns
